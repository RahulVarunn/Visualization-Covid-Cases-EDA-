# %%
import pandas as pd
import numpy as np

data=pd.read_csv('maharastra population.csv')

# %%
data.head()
# Out:
#    s.no         District  population_2011  population_2001  Area(sq km)  \
# 0     1            Thane         11060148          8131849         9558
# 1     2             Pune          9429408          7232555        15643
# 2     3  Mumbai Suburban          9356962          8640419          446
# 3     4           Nashik          6107187          4993796        15530
# 4     5           Nagpur          4653570          4067637         9892
#
#    literacy  Sex ratio(per 1000 boys)
# 0     84.53                       886
# 1     86.15                       915
# 2     89.91                       860
# 3     82.31                       934
# 4     88.39                       951

# %%
data.tail()
# Out:
#     s.no    District  population_2011  population_2001  Area(sq km)  literacy  \
# 30    31    Bhandara          1200334          1136146         4087     83.76
# 31    32      Washim          1197160          1020216         4898     83.25
# 32    33     Hingoli          1177345           987160         4827     78.17
# 33    34  Gadchiroli          1072942           970294        14412     74.36
# 34    35  Sindhudurg           849651           868825         5207     85.56
#
#     Sex ratio(per 1000 boys)
# 30                       982
# 31                       930
# 32                       942
# 33                       982
# 34                      1036

# %%
data.nunique()
# Out:
# s.no                        35
# District                    35
# population_2011             35
# population_2001             35
# Area(sq km)                 35
# literacy                    35
# Sex ratio(per 1000 boys)    30
# dtype: int64

# %%
data.columns.to_list()
# Out:
# ['s.no',
#  'District',
#  'population_2011',
#  'population_2001',
#  'Area(sq km)',
#  'literacy',
#  'Sex ratio(per 1000 boys)']

# %%
data.shape
# Out:
# (35, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   s.no                      35 non-null     int64
#  1   District                  35 non-null     object
#  2   population_2011           35 non-null     int64
#  3   population_2001           35 non-null     int64
#  4   Area(sq km)               35 non-null     int64
#  5   literacy                  35 non-null     float64
#  6   Sex ratio(per 1000 boys)  35 non-null     int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 2.0+ KB

# %%
sorted(data['District'])
# Out:
# ['Ahmadnagar',
#  'Akola',
#  'Amravati',
#  'Aurangabad',
#  'Beed',
#  'Bhandara',
#  'Buldana',
#  'Chandrapur',
#  'Dhule',
#  'Gadchiroli',
#  'Gondiya',
#  'Hingoli',
#  'Jalgaon',
#  'Jalna',
#  'Kolhapur',
#  'Latur',
#  'Mumbai City',
#  'Mumbai Suburban',
#  'Nagpur',
#  'Nanded',
#  'Nandurbar',
#  'Nashik',
#  'Osmanabad',
#  'Parbhani',
#  'Pune',
#  'Raigarh',
#  'Ratnagiri',
#  'Sangli',
#  'Satara',
#  'Sindhudurg',
#  'Solapur',
#  'Thane',
#  'Wardha',
#  'Washim',
#  'Yavatmal']

# %%
data.drop('s.no',axis=1,inplace=True)

# %%
data.dtypes
# Out:
# District                     object
# population_2011               int64
# population_2001               int64
# Area(sq km)                   int64
# literacy                    float64
# Sex ratio(per 1000 boys)      int64
# dtype: object

# %%
data.dtypes[data.dtypes=='int64'].index
# Out:
# Index(['population_2011', 'population_2001', 'Area(sq km)',
#        'Sex ratio(per 1000 boys)'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=35, step=1)

# %%
data.describe(include=[object])
# Out:
#        District
# count        35
# unique       35
# top       Thane
# freq          1

# %%
data.describe(include="all")
# Out:
#        District  population_2011  population_2001   Area(sq km)   literacy  \
# count        35     3.500000e+01     3.500000e+01     35.000000  35.000000
# unique       35              NaN              NaN           NaN        NaN
# top       Thane              NaN              NaN           NaN        NaN
# freq          1              NaN              NaN           NaN        NaN
# mean        NaN     3.210695e+06     2.767961e+06   8791.800000  80.967143
# std         NaN     2.426716e+06     1.934180e+06   4055.060323   5.637003
# min         NaN     8.496510e+05     8.688250e+05    157.000000  64.380000
# 25%         NaN     1.652936e+06     1.507150e+06   6084.500000  77.715000
# 50%         NaN     2.586258e+06     2.207929e+06   8208.000000  82.180000
# 75%         NaN     3.788642e+06     3.430596e+06  11068.000000  84.740000
# max         NaN     1.106015e+07     8.640419e+06  17048.000000  89.910000
#
#         Sex ratio(per 1000 boys)
# count                  35.000000
# ...

# %%
data.describe(exclude=[object])
# Out:
#        population_2011  population_2001   Area(sq km)   literacy  \
# count     3.500000e+01     3.500000e+01     35.000000  35.000000
# mean      3.210695e+06     2.767961e+06   8791.800000  80.967143
# std       2.426716e+06     1.934180e+06   4055.060323   5.637003
# min       8.496510e+05     8.688250e+05    157.000000  64.380000
# 25%       1.652936e+06     1.507150e+06   6084.500000  77.715000
# 50%       2.586258e+06     2.207929e+06   8208.000000  82.180000
# 75%       3.788642e+06     3.430596e+06  11068.000000  84.740000
# max       1.106015e+07     8.640419e+06  17048.000000  89.910000
#
#        Sex ratio(per 1000 boys)
# count                 35.000000
# mean                 947.857143
# std                   47.446653
# min                  832.000000
# 25%                  929.000000
# 50%                  946.000000
# 75%                  960.000000
# max                 1122.000000

# %%
data
# Out:
#            District  population_2011  population_2001  Area(sq km)  literacy  \
# 0             Thane         11060148          8131849         9558     84.53
# 1              Pune          9429408          7232555        15643     86.15
# 2   Mumbai Suburban          9356962          8640419          446     89.91
# 3            Nashik          6107187          4993796        15530     82.31
# 4            Nagpur          4653570          4067637         9892     88.39
# 5        Ahmadnagar          4543159          4040642        17048     79.05
# 6           Solapur          4317756          3849543        14895     77.02
# 7           Jalgaon          4229917          3682690        11765     78.20
# 8          Kolhapur          3876001          3523162         7685     81.51
# 9        Aurangabad          3701282          2897013        10107     79.02
# 10           Nanded          3361292          2876259        10528     75.45
# ...

# %%
x=data['population_2011'].min()
y=data.loc[data['population_2011']==x,'District']
print('Lowest pollulation in 2011 by district: ', y.to_string(index=False)," - ",x)

x=data['population_2011'].max()
y=data.loc[data['population_2011']==x,'District']
print('Highest pollulation in 2011 by district: ', y.to_string(index=False)," - ",x)

print("\n")

x=data['population_2001'].min()
y=data.loc[data['population_2001']==x,'District']
print('Lowest pollulation in 2001 by district: ', y.to_string(index=False)," - ",x)

x=data['population_2001'].max()
y=data.loc[data['population_2001']==x,'District']
print('Highest pollulation in 2001 by district: ', y.to_string(index=False)," - ",x)
# Out:
# Lowest pollulation in 2011 by district:  Sindhudurg  -  849651
# Highest pollulation in 2011 by district:  Thane  -  11060148
#
#
# Lowest pollulation in 2001 by district:  Sindhudurg  -  868825
# Highest pollulation in 2001 by district:  Mumbai Suburban  -  8640419

# %%
missing=np.where(data.isnull()==True)
missing[0]
# Out:
# array([], dtype=int64)

# %%
data.isnull().sum()
# Out:
# District                    0
# population_2011             0
# population_2001             0
# Area(sq km)                 0
# literacy                    0
# Sex ratio(per 1000 boys)    0
# dtype: int64

# %%
list=[]
for i in data['literacy']:
    list.append(i)
    list.sort(reverse=True)
second_largest=list[1]


sec=data.loc[data['literacy']==x,'District']

x=data.loc[data['literacy']==data['literacy'].max(),'District']
y=data.loc[data['literacy']==data['literacy'].min(),'District']
z=data.loc[data['literacy']==data['literacy'].mean(),'District']

print("Highest literacy rate: "+x.to_string(index=False) ,"-" ,data['literacy'].max())
print("Lowest literacy rate:  "+y.to_string(index=False) ,"-"   ,data['literacy'].min())
print("average literacy rate:"  ,data['literacy'].mean())
print("second highest literacy rate : ",sec.to_string(index=False)," ",list[1])

print()
# Out:
# Highest literacy rate: Mumbai Suburban - 89.91
# Lowest literacy rate:  Nandurbar - 64.38
# average literacy rate: 80.96714285714286
# second highest literacy rate :  Series([], )   89.21

# %%
data
# Out:
#            District  population_2011  population_2001  Area(sq km)  literacy  \
# 0             Thane         11060148          8131849         9558     84.53
# 1              Pune          9429408          7232555        15643     86.15
# 2   Mumbai Suburban          9356962          8640419          446     89.91
# 3            Nashik          6107187          4993796        15530     82.31
# 4            Nagpur          4653570          4067637         9892     88.39
# 5        Ahmadnagar          4543159          4040642        17048     79.05
# 6           Solapur          4317756          3849543        14895     77.02
# 7           Jalgaon          4229917          3682690        11765     78.20
# 8          Kolhapur          3876001          3523162         7685     81.51
# 9        Aurangabad          3701282          2897013        10107     79.02
# 10           Nanded          3361292          2876259        10528     75.45
# ...

# %%
x=data.loc[data['Area(sq km)']==data['Area(sq km)'].max(),'District']
y=data.loc[data['Area(sq km)']==data['Area(sq km)'].min(),'District']
z=data.loc[data['Area(sq km)']==data['Area(sq km)'].mean(),'District']

print("Laregest Area/sqkm : "+x.to_string(index=False) ,"-" ,data['Area(sq km)'].max())
print("smallest Area/sqkm:  "+y.to_string(index=False) ,"-"   ,data['Area(sq km)'].min())
# Out:
# Laregest Area/sqkm : Ahmadnagar - 17048
# smallest Area/sqkm:  Mumbai City - 157

# %%
pd.Series(data['District'])
# Out:
# 0               Thane
# 1                Pune
# 2     Mumbai Suburban
# 3              Nashik
# 4              Nagpur
# 5          Ahmadnagar
# 6             Solapur
# 7             Jalgaon
# 8            Kolhapur
# 9          Aurangabad
# 10             Nanded
# 11        Mumbai City
# 12             Satara
# 13           Amravati
# 14             Sangli
# 15           Yavatmal
# 16            Raigarh
# 17            Buldana
# 18               Beed
# 19              Latur
# 20         Chandrapur
# 21              Dhule
# 22              Jalna
# 23           Parbhani
# 24              Akola
# 25          Osmanabad
# 26          Nandurbar
# 27          Ratnagiri
# 28            Gondiya
# 29             Wardha
# 30           Bhandara
# 31             Washim
# 32            Hingoli
# 33         Gadchiroli
# 34         Sindhudurg
# Name: District, dtype: object

# %%
data
# Out:
#            District  population_2011  population_2001  Area(sq km)  literacy  \
# 0             Thane         11060148          8131849         9558     84.53
# 1              Pune          9429408          7232555        15643     86.15
# 2   Mumbai Suburban          9356962          8640419          446     89.91
# 3            Nashik          6107187          4993796        15530     82.31
# 4            Nagpur          4653570          4067637         9892     88.39
# 5        Ahmadnagar          4543159          4040642        17048     79.05
# 6           Solapur          4317756          3849543        14895     77.02
# 7           Jalgaon          4229917          3682690        11765     78.20
# 8          Kolhapur          3876001          3523162         7685     81.51
# 9        Aurangabad          3701282          2897013        10107     79.02
# 10           Nanded          3361292          2876259        10528     75.45
# ...

# %%
# x=data[24:33]
# x['population_2011'].sum()

# data.loc[24:33,'population_2011'].sum()
data.loc[0:].sum()
# Out:
# District                    ThanePuneMumbai SuburbanNashikNagpurAhmadnagar...
# population_2011                                                     112374333
# population_2001                                                      96878627
# Area(sq km)                                                            307713
# literacy                                                              2833.85
# Sex ratio(per 1000 boys)                                                33175
# dtype: object

# %%
x=data.loc[0:11,'population_2011'].sum()
print("sum of 10th population(2011) : ",x)
# Out:
# sum of 10th population(2011) :  67722093

# %%
data.shape
# Out:
# (35, 6)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (30, 15))

plt.plot(data['District'].head(18),data['literacy'].head(18),marker='D',color='orange',label="Literacy")
plt.title("Literacy Rate",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\n\nLiteracy rate",fontsize=15)
plt.xlabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=20)
plt.grid(color="gray",linewidth=0.5)
plt.show()



plt.figure(figsize = (30, 15))
plt.plot(data['District'].tail(17),data['literacy'].tail(17),marker='D',color='orange',label="Literacy")
plt.title("Literacy Rate",fontsize=20)

plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\n\nLiteracy rate",fontsize=15)
plt.xlabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=20)
plt.grid(color="gray",linewidth=0.5)

plt.show()

# %%
data[['population_2011','population_2001']].max()
# Out:
# population_2011    11060148
# population_2001     8640419
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (30, 15))

plt.scatter(data['District'].head(18),data['population_2001'].head(18),marker='o',label="Population 2001")
plt.scatter(data['District'].head(18),data['population_2011'].head(18),marker='o',label="population 2011")
plt.title("Population",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\nPopulation rate",fontsize=15)
plt.xlabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)
plt.show()



plt.figure(figsize = (30, 15))

plt.scatter(data['District'].tail(17),data['population_2001'].tail(17),marker='o',label="population 2001")
plt.scatter(data['District'].tail(17),data['population_2011'].tail(17),marker='o',label="population 2011")
plt.title("Population",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\n\Population rate",fontsize=15)
plt.xlabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (35, 15))

plt.bar(data['District'].head(18),data['population_2001'].head(18),color='green',label="Literacy")
plt.bar(data['District'].head(18),data['population_2011'].head(18),color='lightcoral',label="Literacy")


plt.title("Literacy Rate",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\n\nLiteracy rate",fontsize=15)
plt.xlabel("\n\nPOPULATION",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)


plt.show()



plt.figure(figsize = (30, 15))

plt.bar(data['District'].tail(17),data['population_2001'].tail(17),color='green',label="population 2001")
plt.bar(data['District'].tail(17),data['population_2011'].tail(17),color='lightcoral',label="population 2011")

plt.title("POPULATION",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\n\nLiteracy rate",fontsize=15)
plt.xlabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (30, 15))

plt.barh(data['District'],data['population_2001'],color='green',label="population 2001")
plt.barh(data['District'],data['population_2011'],color='lightcoral',label="population 2011")

plt.title("POPULATION",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.xlabel("\n\nLiteracy rate",fontsize=15)
plt.ylabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)



plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (30, 15))

plt.barh(data['District'].head(18),data['Area(sq km)'].head(18),color='green',label="Area/Sq Km")

plt.title("\nAREA COVERED BY DISTRICT\n",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.xlabel("\n\nArea(sq km)",fontsize=15)
plt.ylabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)
# plt.show()




plt.show()

# %%
plt.figure(figsize = (20, 20))

x=data[['population_2011','population_2001']].sum()
y=data[['population_2011','population_2001']].columns.to_list()

plt.pie(x,autopct='%1.1f%%',labels=y,startangle=0,shadow=True)

plt.title("\n\nPERCENT OF POPULATION")
plt.legend(fontsize=20)
plt.show()

# %%
figure=plt.figure(figsize = (30, 15))
ax=figure.add_axes([0,0,1,1])
ax.bar(data['District']  ,data['population_2001'],color='skyblue',label='population 2001')
ax.bar(data['District'] ,data['population_2011'],width = 0.5, align='edge',color='orange',label='population 2011')
plt.xticks(rotation=90,fontsize=20)
plt.legend(fontsize=30)
plt.grid(linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (30, 15))

plt.plot(data['District'].head(18),data['Sex ratio(per 1000 boys)'].head(18),marker='D',color='orange',label="Literacy")
plt.title(" SEX RATIO FOR FIRST 17 DISTRICT",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\n\nSex ratio(per 1000 boys)",fontsize=15)
plt.xlabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)
plt.show()



plt.figure(figsize = (30, 15))
plt.plot(data['District'].tail(17),data['Sex ratio(per 1000 boys)'].tail(17),marker='D',color='orange',label="Sex Ratio")
plt.title("Literacy Rate",fontsize=20)

plt.title("SEX RATIO FOR LAST 18 DISTRICT",fontsize=20)
plt.xticks(size = 10)
plt.yticks(size = 15)
plt.ylabel("\n\nSex ratio(per 1000 boys)",fontsize=15)
plt.xlabel("\n\nNo of District",fontsize=15)
plt.legend(loc=1,fontsize=15)
plt.grid(color="gray",linewidth=0.5)

plt.show()

# %%
data[['population_2011','population_2001']].min()
# Out:
# population_2011    849651
# population_2001    868825
# dtype: int64

# %%
data[['population_2011','population_2001']].max()
# Out:
# population_2011    11060148
# population_2001     8640419
# dtype: int64
